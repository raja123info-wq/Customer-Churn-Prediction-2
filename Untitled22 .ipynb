# %%
# Customer Churn — EDA, Preprocessing, Logistic Regression (with CV & interpretation)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, classification_report, roc_curve, precision_recall_curve, auc
)
from sklearn.impute import SimpleImputer
import pickle
import os

# ---------- CONFIG ----------
DATA_PATH = r"/content/Telco-Customer-Churn.csv"
MODEL_PATH = "churn_model.pkl"
RANDOM_STATE = 42
TEST_SIZE = 0.20
CV_FOLDS = 5
# ----------------------------

# 1) LOAD
try:
    df = pd.read_csv(DATA_PATH)
    print("✅ Loaded dataset shape:", df.shape)
    display(df.head())
except FileNotFoundError:
    print(f"❌ Error: File not found at {DATA_PATH}")
    print("Please check the file path and ensure the CSV exists.")
    raise

# 2) QUICK OVERVIEW
print("\n--- Info & Nulls ---")
print(df.info())
print("\nMissing values per column:\n", df.isnull().sum())

# Some Telco datasets have 'TotalCharges' as object with spaces -> convert
if 'TotalCharges' in df.columns:
    df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
    print("\nTotalCharges after conversion - nulls:", df['TotalCharges'].isnull().sum())
    if df['TotalCharges'].isnull().sum() > 0:
        df = df.dropna(subset=['TotalCharges']).reset_index(drop=True)
        print("Dropped rows with missing TotalCharges. New shape:", df.shape)

# 3) Basic cleaning
# Drop customerID if present
if 'customerID' in df.columns:
    df = df.drop(columns=['customerID'])

# Map target
if 'Churn' in df.columns:
    df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})
    print("Churn value counts:\n", df['Churn'].value_counts())

# 4) EDA — distributions & relationships
# Separate numerical and categorical
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
num_cols = [c for c in num_cols if c != 'Churn']  # exclude target
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

print("\nNumerical cols:", num_cols)
print("Categorical cols:", cat_cols)

# Univariate numeric distributions
plt.figure(figsize=(14,4))
for i, col in enumerate(num_cols):
    plt.subplot(1, len(num_cols), i+1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# Target vs numerical boxplots / violin to see relationship
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x='Churn', y=col, data=df)
    plt.title(f"{col} by Churn")
    plt.show()

# Categorical distributions (bar) and churn rate by category
for col in cat_cols:
    counts = df[col].value_counts()
    if len(counts) > 20:
        top = counts.nlargest(10)
        print(f"\n{col} (top 10 counts):\n", top)
    else:
        plt.figure(figsize=(8,3))
        sns.countplot(data=df, x=col, order=df[col].value_counts().index)
        plt.xticks(rotation=45)
        plt.title(f"Counts for {col}")
        plt.show()

    churn_pct = df.groupby(col)['Churn'].mean().sort_values(ascending=False)
    display(churn_pct.to_frame(name='churn_rate').head(10))

# Correlation heatmap for numeric variables (including target)
plt.figure(figsize=(6,5))
sns.heatmap(df[num_cols + ['Churn']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Numeric Correlations (incl. Churn)")
plt.show()

# Categorical features correlation with churn
overall_churn = df['Churn'].mean()
cat_churn_impacts = []
for col in cat_cols:
    rates = df.groupby(col)['Churn'].mean()
    spread = rates.max() - rates.min()
    cat_churn_impacts.append((col, spread))
cat_churn_impacts = sorted(cat_churn_impacts, key=lambda x: x[1], reverse=True)
print("Categorical features sorted by churn-rate spread (top 10):")
for col, spread in cat_churn_impacts[:10]:
    print(f"{col}: spread = {spread:.3f}")

# 5) PREPROCESSING
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, num_cols),
    ('cat', categorical_transformer, cat_cols)
], remainder='drop')

# 6) TRAIN-TEST SPLIT
X = df.drop(columns=['Churn'])
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y
)
print("\nTrain shape:", X_train.shape, "Test shape:", X_test.shape)
print("Train churn rate:", y_train.mean(), "Test churn rate:", y_test.mean())

# 7) PIPELINE with Logistic Regression and CV
pipe = Pipeline(steps=[
    ('preproc', preprocessor),
    ('clf', LogisticRegression(solver='liblinear', max_iter=1000, class_weight='balanced', random_state=RANDOM_STATE))
])

param_grid = {
    'clf__C': [0.01, 0.1, 1.0, 5.0, 10.0],
    'clf__penalty': ['l1', 'l2']
}

cv = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)
grid = GridSearchCV(pipe, param_grid, cv=cv, scoring='roc_auc', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

print("\n Best params:", grid.best_params_)
print(" Best CV ROC AUC:", grid.best_score_)

best_model = grid.best_estimator_

# 8) EVALUATE on test set
y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, zero_division=0)
rec = recall_score(y_test, y_pred, zero_division=0)
f1 = f1_score(y_test, y_pred, zero_division=0)
roc = roc_auc_score(y_test, y_prob)

print("\n--- Test set performance ---")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1-score:  {f1:.4f}")
print(f"ROC AUC:   {roc:.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, digits=4))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4,3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1], yticklabels=[0,1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label=f'ROC AUC = {roc:.3f}')
plt.plot([0,1],[0,1],'--', alpha=0.6)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# Precision-Recall curve
precision_vals, recall_vals, pr_thresholds = precision_recall_curve(y_test, y_prob)
pr_auc = auc(recall_vals, precision_vals)
plt.figure(figsize=(6,4))
plt.plot(recall_vals, precision_vals, label=f'PR AUC = {pr_auc:.3f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# 9) FEATURE IMPORTANCE: map coefficients back to feature names
ohe = best_model.named_steps['preproc'].named_transformers_['cat'].named_steps['onehot']
num_after = num_cols

# Build feature names list
cat_feature_names = []
if hasattr(ohe, 'get_feature_names_out'):
    cat_feature_names = ohe.get_feature_names_out(cat_cols)
else:
    for i, col in enumerate(cat_cols):
        cats = best_model.named_steps['preproc'].named_transformers_['cat'].named_steps['onehot'].categories_[i][1:]
        cat_feature_names += [f"{col}_{c}" for c in cats]

feature_names = list(cat_feature_names) + list(num_after)

coefs = best_model.named_steps['clf'].coef_[0]
coef_df = pd.DataFrame({'feature': feature_names, 'coef': coefs})
coef_df['abs_coef'] = coef_df['coef'].abs()
coef_df = coef_df.sort_values(by='abs_coef', ascending=False).reset_index(drop=True)
display(coef_df.head(20))

print("\nTop features increasing churn (positive coefficients):")
display(coef_df[coef_df['coef']>0].head(10))

print("\nTop features decreasing churn (negative coefficients):")
display(coef_df[coef_df['coef']<0].head(10))

print("\nInterpretation guidance:")
print("- Positive coefficient = increases churn probability")
print("- Negative coefficient = decreases churn probability")

# 10) THRESHOLD EXPLORATION
thresholds = np.linspace(0.01, 0.99, 99)
metrics = []
for th in thresholds:
    y_th = (y_prob >= th).astype(int)
    metrics.append({
        'threshold': th,
        'precision': precision_score(y_test, y_th, zero_division=0),
        'recall': recall_score(y_test, y_th, zero_division=0),
        'f1': f1_score(y_test, y_th, zero_division=0)
    })
metrics_df = pd.DataFrame(metrics)
plt.figure(figsize=(8,4))
plt.plot(metrics_df['threshold'], metrics_df['precision'], label='Precision')
plt.plot(metrics_df['threshold'], metrics_df['recall'], label='Recall')
plt.plot(metrics_df['threshold'], metrics_df['f1'], label='F1')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Precision / Recall / F1 vs threshold')
plt.legend()
plt.show()

# 11) SAVE MODEL
try:
    with open(MODEL_PATH, 'wb') as f:
        pickle.dump(best_model, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"\n✅ Model saved successfully to '{MODEL_PATH}'")
except Exception as e:
    print(f"❌ Error saving model: {str(e)}")

print("\n✅ Done. Script completed.")
# Out:
# ✅ Loaded dataset shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Task
# Summarize the key findings from the Exploratory Data Analysis (EDA) and the detailed preprocessing steps applied to the dataset in the notebook. Then, provide the complete runnable Python code used for data preparation, modeling, and evaluation. After that, analyze the model's performance metrics (Accuracy, Precision, Recall, F1-Score, ROC AUC) and interpret the feature importances (coefficients) to identify the top three most predictive features for customer churn, including strategic business recommendations based on these insights. Finally, provide a concluding summary of the churn prediction analysis.

# %% [markdown]
# ## Summarize EDA and Preprocessing
#
# ### Subtask:
# Provide a text-based summary of the key findings from the Exploratory Data Analysis (EDA) and the detailed preprocessing steps applied to the dataset, as performed in the existing comprehensive code.

# %% [markdown]
# ### Summary of EDA and Preprocessing
#
# #### Exploratory Data Analysis (EDA) Findings:
#
# 1.  **Initial Data Overview & Cleaning**: The dataset initially contained 7043 rows and 21 columns. The `TotalCharges` column, identified as an object type, was converted to numeric, resulting in 11 missing values which were subsequently dropped, reducing the dataset to 7032 rows. The `customerID` column was dropped, and the `Churn` target variable was mapped from 'Yes'/'No' to 1/0 for modeling.
# 2.  **Feature Identification**: Four numerical columns (`SeniorCitizen`, `tenure`, `MonthlyCharges`, `TotalCharges`) and fifteen categorical columns were identified.
# 3.  **Numerical Feature Insights**:
#     *   `tenure`: Shows a wide distribution, with a tendency for shorter tenures to have higher churn rates (as seen in boxplots).
#     *   `MonthlyCharges`: Higher monthly charges tend to correlate with higher churn.
#     *   `TotalCharges`: Lower total charges are associated with higher churn, which makes sense given the tenure-churn relationship.
#     *   `SeniorCitizen`: Being a senior citizen (1) appears to have a higher churn rate compared to non-senior citizens (0).
# 4.  **Categorical Feature Insights**:
#     *   **High Impact on Churn**: Features like `Contract` (Month-to-month contracts have a significantly higher churn rate than One year or Two year contracts), `InternetService` (Fiber optic service shows higher churn), `OnlineSecurity`, `TechSupport`, and `OnlineBackup` (customers without these services churn more) show the largest spread in churn rates across their categories.
#     *   `PaymentMethod`: Electronic check payment method has a noticeably higher churn rate.
#     *   `PaperlessBilling`: Customers with paperless billing show a higher churn rate.
# 5.  **Correlations**: Numerical features like `tenure` and `TotalCharges` are positively correlated with each other and negatively correlated with `MonthlyCharges`. Churn generally shows a negative correlation with `tenure` and `TotalCharges`, and a positive correlation with `MonthlyCharges`.
#
# #### Preprocessing Steps:
#
# 1.  **Feature Separation**: The dataset was split into features (X) and target (y) with `Churn` as the target variable.
# 2.  **Train-Test Split**: The data was divided into training (80%) and testing (20%) sets using `train_test_split`, ensuring stratification based on the `Churn` variable to maintain the target distribution in both sets.
# 3.  **Column Transformers**: A `ColumnTransformer` was set up to apply different preprocessing steps to numerical and categorical features:
#     *   **Numerical Transformer**: A `Pipeline` consisting of a `SimpleImputer` (median strategy) to handle any potential missing numerical values, followed by `StandardScaler` for feature scaling (standardizing to zero mean and unit variance).
#     *   **Categorical Transformer**: A `Pipeline` consisting of a `SimpleImputer` (most frequent strategy) to handle any potential missing categorical values, followed by `OneHotEncoder` to convert categorical features into a numerical format, dropping the first category to avoid multicollinearity (`drop='first'`) and handling unknown categories (`handle_unknown='ignore'`)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, classification_report, roc_curve, precision_recall_curve, auc
)
from sklearn.impute import SimpleImputer
import pickle
import os

# ---------- CONFIG ----------
DATA_PATH = r"/content/Telco-Customer-Churn.csv"
MODEL_PATH = "churn_model.pkl"
RANDOM_STATE = 42
TEST_SIZE = 0.20
CV_FOLDS = 5
# ----------------------------

# 1) LOAD
try:
    df = pd.read_csv(DATA_PATH)
    print(" Loaded dataset shape:", df.shape)
    display(df.head())
except FileNotFoundError:
    print(f" Error: File not found at {DATA_PATH}")
    print("Please check the file path and ensure the CSV exists.")
    raise

# 2) QUICK OVERVIEW
print("\n--- Info & Nulls ---")
print(df.info())
print("\nMissing values per column:\n", df.isnull().sum())

# Some Telco datasets have 'TotalCharges' as object with spaces -> convert
if 'TotalCharges' in df.columns:
    df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
    print("\nTotalCharges after conversion - nulls:", df['TotalCharges'].isnull().sum())
    if df['TotalCharges'].isnull().sum() > 0:
        df = df.dropna(subset=['TotalCharges']).reset_index(drop=True)
        print("Dropped rows with missing TotalCharges. New shape:", df.shape)

# 3) Basic cleaning
# Drop customerID if present
if 'customerID' in df.columns:
    df = df.drop(columns=['customerID'])

# Map target
if 'Churn' in df.columns:
    df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})
    print("Churn value counts:\n", df['Churn'].value_counts())

# 4) EDA — distributions & relationships
# Separate numerical and categorical
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
num_cols = [c for c in num_cols if c != 'Churn']  # exclude target
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

print("\nNumerical cols:", num_cols)
print("Categorical cols:", cat_cols)

# Univariate numeric distributions
plt.figure(figsize=(14,4))
for i, col in enumerate(num_cols):
    plt.subplot(1, len(num_cols), i+1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# Target vs numerical boxplots / violin to see relationship
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x='Churn', y=col, data=df)
    plt.title(f"{col} by Churn")
    plt.show()

# Categorical distributions (bar) and churn rate by category
for col in cat_cols:
    counts = df[col].value_counts()
    if len(counts) > 20:
        top = counts.nlargest(10)
        print(f"\n{col} (top 10 counts):\n", top)
    else:
        plt.figure(figsize=(8,3))
        sns.countplot(data=df, x=col, order=df[col].value_counts().index)
        plt.xticks(rotation=45)
        plt.title(f"Counts for {col}")
        plt.show()

    churn_pct = df.groupby(col)['Churn'].mean().sort_values(ascending=False)
    display(churn_pct.to_frame(name='churn_rate').head(10))

# Correlation heatmap for numeric variables (including target)
plt.figure(figsize=(6,5))
sns.heatmap(df[num_cols + ['Churn']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Numeric Correlations (incl. Churn)")
plt.show()

# Categorical features correlation with churn
overall_churn = df['Churn'].mean()
cat_churn_impacts = []
for col in cat_cols:
    rates = df.groupby(col)['Churn'].mean()
    spread = rates.max() - rates.min()
    cat_churn_impacts.append((col, spread))
cat_churn_impacts = sorted(cat_churn_impacts, key=lambda x: x[1], reverse=True)
print("Categorical features sorted by churn-rate spread (top 10):")
for col, spread in cat_churn_impacts[:10]:
    print(f"{col}: spread = {spread:.3f}")

# 5) PREPROCESSING
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, num_cols),
    ('cat', categorical_transformer, cat_cols)
], remainder='drop')

# 6) TRAIN-TEST SPLIT
X = df.drop(columns=['Churn'])
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y
)
print("\nTrain shape:", X_train.shape, "Test shape:", X_test.shape)
print("Train churn rate:", y_train.mean(), "Test churn rate:", y_test.mean())

# 7) PIPELINE with Logistic Regression and CV
pipe = Pipeline(steps=[
    ('preproc', preprocessor),
    ('clf', LogisticRegression(solver='liblinear', max_iter=1000, class_weight='balanced', random_state=RANDOM_STATE))
])

param_grid = {
    'clf__C': [0.01, 0.1, 1.0, 5.0, 10.0],
    'clf__penalty': ['l1', 'l2']
}

cv = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)
grid = GridSearchCV(pipe, param_grid, cv=cv, scoring='roc_auc', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

print("\n Best params:", grid.best_params_)
print(" Best CV ROC AUC:", grid.best_score_)

best_model = grid.best_estimator_

# 8) EVALUATE on test set
y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, zero_division=0)
rec = recall_score(y_test, y_pred, zero_division=0)
f1 = f1_score(y_test, y_pred, zero_division=0)
roc = roc_auc_score(y_test, y_prob)

print("\n--- Test set performance ---")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1-score:  {f1:.4f}")
print(f"ROC AUC:   {roc:.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, digits=4))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4,3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1], yticklabels=[0,1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label=f'ROC AUC = {roc:.3f}')
plt.plot([0,1],[0,1],'--', alpha=0.6)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# Precision-Recall curve
precision_vals, recall_vals, pr_thresholds = precision_recall_curve(y_test, y_prob)
pr_auc = auc(recall_vals, precision_vals)
plt.figure(figsize=(6,4))
plt.plot(recall_vals, precision_vals, label=f'PR AUC = {pr_auc:.3f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# 9) FEATURE IMPORTANCE: map coefficients back to feature names
ohe = best_model.named_steps['preproc'].named_transformers_['cat'].named_steps['onehot']
num_after = num_cols

# Build feature names list
cat_feature_names = []
if hasattr(ohe, 'get_feature_names_out'):
    cat_feature_names = ohe.get_feature_names_out(cat_cols)
else:
    for i, col in enumerate(cat_cols):
        cats = best_model.named_steps['preproc'].named_transformers_['cat'].named_steps['onehot'].categories_[i][1:]
        cat_feature_names += [f"{col}_{c}" for c in cats]

feature_names = list(cat_feature_names) + list(num_after)

coefs = best_model.named_steps['clf'].coef_[0]
coef_df = pd.DataFrame({'feature': feature_names, 'coef': coefs})
coef_df['abs_coef'] = coef_df['coef'].abs()
coef_df = coef_df.sort_values(by='abs_coef', ascending=False).reset_index(drop=True)
display(coef_df.head(20))

print("\nTop features increasing churn (positive coefficients):")
display(coef_df[coef_df['coef']>0].head(10))

print("\nTop features decreasing churn (negative coefficients):")
display(coef_df[coef_df['coef']<0].head(10))

print("\nInterpretation guidance:")
print("- Positive coefficient = increases churn probability")
print("- Negative coefficient = decreases churn probability")

# 10) THRESHOLD EXPLORATION
thresholds = np.linspace(0.01, 0.99, 99)
metrics = []
for th in thresholds:
    y_th = (y_prob >= th).astype(int)
    metrics.append({
        'threshold': th,
        'precision': precision_score(y_test, y_th, zero_division=0),
        'recall': recall_score(y_test, y_th, zero_division=0),
        'f1': f1_score(y_test, y_th, zero_division=0)
    })
metrics_df = pd.DataFrame(metrics)
plt.figure(figsize=(8,4))
plt.plot(metrics_df['threshold'], metrics_df['precision'], label='Precision')
plt.plot(metrics_df['threshold'], metrics_df['recall'], label='Recall')
plt.plot(metrics_df['threshold'], metrics_df['f1'], label='F1')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Precision / Recall / F1 vs threshold')
plt.legend()
plt.show()

# 11) SAVE MODEL
try:
    with open(MODEL_PATH, 'wb') as f:
        pickle.dump(best_model, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"\n Model saved successfully to '{MODEL_PATH}'")
except Exception as e:
    print(f" Error saving model: {str(e)}")

print("\n Done. Script completed.")
# Out:
#  Loaded dataset shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Model Performance Analysis
#
# The Logistic Regression model was evaluated on the test set, yielding the following key performance metrics:
#
# *   **Accuracy: 0.7257**
#     *   Accuracy measures the proportion of true results (both true positives and true negatives) among the total number of cases examined. An accuracy of 72.57% means that the model correctly classified approximately 72.57% of customers as either churning or not churning.
#
# *   **Precision (for Churn=1): 0.4901**
#     *   Precision is the ratio of correctly predicted positive observations to the total predicted positive observations. For churn prediction, a precision of 49.01% means that when the model predicts a customer will churn, it is correct about 49.01% of the time. This metric is crucial to minimize false positives (predicting churn when a customer doesn't, leading to wasted retention efforts).
#
# *   **Recall (for Churn=1): 0.7968**
#     *   Recall (also known as Sensitivity) is the ratio of correctly predicted positive observations to all observations in the actual class. A recall of 79.68% indicates that the model correctly identified 79.68% of all actual churners. This metric is important to minimize false negatives (failing to identify actual churners, which means lost customers).
#
# *   **F1-Score (for Churn=1): 0.6069**
#     *   The F1-Score is the weighted average of Precision and Recall. It tries to find the balance between precision and recall. An F1-score of 0.6069 suggests a reasonable balance, especially useful when there is an uneven class distribution (as is often the case with churn).
#
# *   **ROC AUC: 0.8346**
#     *   The Receiver Operating Characteristic Area Under the Curve (ROC AUC) measures the ability of the model to distinguish between positive and negative classes. An AUC of 0.8346 (83.46%) indicates a good separability between churners and non-churners. The closer AUC is to 1, the better the model is at predicting 0s as 0s and 1s as 1s. A random classifier would have an AUC of 0.5.
#
# ### Overall Interpretation:
# The model demonstrates a good capability to identify actual churners (high recall) and good discrimination (high ROC AUC). However, its precision is relatively lower, suggesting that while it catches most churners, it also incorrectly flags a significant portion of non-churners as potential churners. This trade-off between precision and recall is common in imbalanced datasets and depends on the business objective (is it more critical to catch all churners even if some non-churners are mistakenly targeted, or to only target definite churners?). The chosen `class_weight='balanced'` and `scoring='roc_auc'` during GridSearchCV likely aimed to optimize this balance, prioritizing the overall discriminatory power rather than solely accuracy.

# %% [markdown]
# ## Feature Importance and Business Recommendations
#
# Based on the Logistic Regression model's coefficients, the features with the highest absolute values are the most impactful in predicting customer churn. These coefficients indicate the direction and strength of the relationship between a feature and the likelihood of churn.
#
# ### Top Three Most Predictive Features:
#
# 1.  **OnlineBackup_No internet service** (Coefficient: `2.15`)
#     *   **Interpretation**: This feature has the largest positive coefficient, indicating that customers who **do not have online backup service (but do have internet service)** are significantly more likely to churn. This suggests a strong correlation between the lack of this service and churn.
#     *   **Strategic Business Recommendation**: Proactively offer online backup services to customers, especially those with internet service but without this add-on. Highlight the benefits of data security and ease of recovery. Consider bundling it with existing plans or offering promotional periods to encourage adoption.
#
# 2.  **Dependents_Yes** (Coefficient: `-1.72`)
#     *   **Interpretation**: This feature has a large negative coefficient, meaning that customers who **have dependents** are significantly less likely to churn. This group might value stability and comprehensive plans, making them more loyal to the service provider.
#     *   **Strategic Business Recommendation**: Identify customers with dependents and create targeted retention campaigns that emphasize family-friendly packages, discounted rates for multiple lines/services, or loyalty programs. Ensure customer support is responsive to their potentially complex needs.
#
# 3.  **PaymentMethod_Mailed check** (Coefficient: `-1.49`)
#     *   **Interpretation**: This feature also has a large negative coefficient, indicating that customers who pay via **mailed check** are less likely to churn compared to other payment methods (after one-hot encoding, this is the reference category for `PaymentMethod_Electronic check`, `PaymentMethod_Bank transfer (automatic)`, and `PaymentMethod_Credit card (automatic)`). While the raw coefficient is negative, in context, it's often more informative to look at the other payment methods' coefficients relative to this baseline. However, if 'Mailed check' itself is showing as a strong *negative* predictor of churn when directly compared to other payment methods as seen in the top decreasing churn features, it implies that customers using this method are generally more stable. *Correction*: Looking at `coef_df` more carefully, the coefficient for `PaymentMethod_Mailed check` is negative, suggesting that customers using this specific method are *less prone to churn* compared to the overall average. Conversely, `PaymentMethod_Electronic check` (coef: -0.80) and `PaymentMethod_Credit card (automatic)` (coef: 0.78) are also highly ranked, meaning their presence might slightly decrease or increase churn relative to the baseline or other payment types. Let's re-evaluate based on the absolute highest:
#
# ### Re-evaluating Top 3 by Absolute Coefficient:
#
# 1.  **OnlineBackup_No internet service** (Coefficient: `2.15`)
#     *   **Interpretation**: Customers who **do not have online backup service (and thus also no internet service, as 'no internet service' bundles these)** are highly likely to churn. This is the strongest positive indicator of churn.
#     *   **Strategic Business Recommendation**: Offer internet service packages that include online backup to customers currently without these services. For existing customers without online backup (and potentially no internet), target them with promotions for bundled services, highlighting the value and necessity of comprehensive digital solutions.
#
# 2.  **Dependents_Yes** (Coefficient: `-1.72`)
#     *   **Interpretation**: Customers who **have dependents** are significantly less likely to churn. This group represents a stable customer base.
#     *   **Strategic Business Recommendation**: Implement loyalty programs and personalized offers for customers with dependents to reinforce their stability and encourage long-term retention. Use data to understand their specific needs and tailor services or bundles accordingly.
#
# 3.  **Partner_Yes** (Coefficient: `-1.29`)
#     *   **Interpretation**: Customers who **have a partner** are significantly less likely to churn. Similar to 'Dependents_Yes', this indicates a more stable household.
#     *   **Strategic Business Recommendation**: Develop retention strategies focusing on customers with partners, potentially offering multi-user plans or bundled services that cater to household needs. Promote the benefits of staying with the provider for joint household management.
#
# ### General Strategic Recommendations:
#
# *   **Focus on Service Bundling**: The high positive coefficient for lacking internet-related services (like online backup) suggests that customers without comprehensive service bundles are more prone to churn. Encourage adoption of higher-tier or bundled services that include these valuable add-ons.
# *   **Enhance Loyalty for Stable Segments**: Customers with dependents and partners show higher loyalty. Invest in understanding and rewarding these segments to maximize their lifetime value.
# *   **Targeted Outreach**: Utilize these insights to create highly targeted churn prevention campaigns. Instead of generic offers, tailor interventions based on specific feature deficiencies or customer demographics identified as high-risk.
#
# These recommendations aim to leverage the model's interpretability to guide actionable business decisions, improving customer retention by addressing the root causes and indicators of churn.

# %% [markdown]
# ## Concluding Summary of Churn Prediction Analysis
#
# This project embarked on a comprehensive analysis of customer churn within a telecommunications dataset, employing a Logistic Regression model for prediction and interpretation. The process began with thorough Exploratory Data Analysis (EDA) and meticulous preprocessing.
#
# ### Key Stages and Findings:
#
# 1.  **Data Loading & Initial Cleaning**: The dataset was loaded, `TotalCharges` was cleaned by converting to numeric and dropping rows with missing values, and the `customerID` was removed. The `Churn` target variable was binary-encoded (Yes=1, No=0).
# 2.  **Exploratory Data Analysis (EDA)**: EDA revealed crucial insights: shorter `tenure`, higher `MonthlyCharges`, `Month-to-month` contracts, `Fiber optic` internet service, lack of `OnlineSecurity` and `TechSupport`, and `Electronic check` payment method were strongly associated with higher churn rates. Conversely, customers with `Dependents` and `Partners` showed lower churn rates.
# 3.  **Preprocessing**: Numerical features (`SeniorCitizen`, `tenure`, `MonthlyCharges`, `TotalCharges`) were imputed with the median and scaled using `StandardScaler`. Categorical features were imputed with the most frequent value and then one-hot encoded using `OneHotEncoder(drop='first')` to handle nominal data and prevent multicollinearity. This was orchestrated efficiently using `ColumnTransformer` within a `Pipeline`.
# 4.  **Model Training & Evaluation**: A Logistic Regression model, tuned with `GridSearchCV` using `StratifiedKFold` and `roc_auc` scoring, was trained on the preprocessed data. The model achieved a **ROC AUC of 0.8346** on the test set, indicating good discriminatory power. It showed a **Recall of 0.7968** (identifying most churners) and a **Precision of 0.4901** (meaning about half of its positive churn predictions were correct), with an **F1-score of 0.6069**. This balance of recall over precision is often desirable in churn scenarios to capture as many potential churners as possible.
# 5.  **Feature Importance**: Analysis of the model's coefficients highlighted the most influential factors:
#     *   **Strongest positive predictor of churn**: `OnlineBackup_No internet service` (customers lacking online backup service and internet service are highly prone to churn).
#     *   **Strongest negative predictors of churn**: `Dependents_Yes` and `Partner_Yes` (customers with dependents or partners are significantly less likely to churn).
#
# ### Strategic Business Recommendations:
#
# The analysis provides clear actionable insights for customer retention efforts:
#
# *   **Bundle Services**: Proactively offer internet service packages that include valuable add-ons like online backup to customers currently without these services. Highlight the benefits of comprehensive digital solutions.
# *   **Nurture Loyal Segments**: Implement targeted loyalty programs and personalized offers for customers with dependents and partners, as these segments demonstrate higher retention. Leverage their stability by understanding and meeting their specific household needs.
# *   **Targeted Intervention**: Develop focused churn prevention campaigns based on specific risk factors. For instance, customers on month-to-month contracts or using Fiber Optic internet without security features might be prime candidates for specific retention offers or support.
#
# In conclusion, the Logistic Regression model effectively identified key drivers of churn, providing a robust framework for predicting customer attrition and guiding strategic interventions to improve customer retention.

# %% [markdown]
# ## Summarize EDA and Preprocessing
#
# ### Subtask:
# Provide a text-based summary of the key findings from the Exploratory Data Analysis (EDA) and the detailed preprocessing steps applied to the dataset, as performed in the existing comprehensive code.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The subtask, which required a summary of Exploratory Data Analysis (EDA) and preprocessing steps, was found to be entirely fulfilled by an existing, comprehensive text cell (ID `86ad5da8`).
# *   The pre-existing summary covered essential details such as initial data overview, data cleaning, feature identification, insights from data distributions and their relationship with churn, and a complete description of the preprocessing pipeline, including the train-test split and `ColumnTransformer` specifics.
#
# ### Insights or Next Steps
# *   The successful completion of this subtask without new code generation indicates robust documentation within the existing analysis.
# *   Future tasks can leverage this existing documentation efficiently, ensuring consistency and reducing redundant work.
